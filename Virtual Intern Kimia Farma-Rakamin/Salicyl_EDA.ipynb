# %% [markdown]
# # Connect to Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
dir = '/content/drive/MyDrive/Portofolio/Virtual Intern Kimia Farma-Rakamin'
os.chdir(dir)

# %%
# !ls
# Out:
#  datamart_aggregate1.sql   Datamart_Salicyl.csv
#  datamart_base.sql	  'SALICYL_SALES__DASHBOARD .pdf'

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv('Datamart_Salicyl.csv', header=None)

df.head()
# Out:
#         0                                          1   2    3   4    5     6   \
# 0  BRG0005  KLORPROMAZINA TABLET SALUT SELAPUT 100 MG   1  DUS  10   10  5648
# 1  BRG0010                                PARACETAMOL   4  DUS   1    4  6940
# 2  BRG0005  KLORPROMAZINA TABLET SALUT SELAPUT 100 MG  12  DUS  10  120  5648
# 3  BRG0010                                PARACETAMOL  15  DUS   1   15  6940
# 4  BRG0005  KLORPROMAZINA TABLET SALUT SELAPUT 100 MG  18  DUS  10  180  5648
#
#         7          8      9          10                11        12  \
# 0    56480  CUST55384  CAB04  Tangerang    KLINIK SAHABAT  Klinik\r
# 1    27760  CUST55389  CAB09    Jakarta         KLINIK GM  Klinik\r
# 2   677760  CUST55394  CAB03    Lampung  KLINIK DR. ANDRI  Klinik\r
# 3   104100  CUST55399  CAB08  Tangerang    KLINIK SAHABAT  Klinik\r
# 4  1016640  CUST55404  CAB02    Jakarta         KLINIK GM  Klinik\r
#
#            13       14
# 0  2022-01-23  SLCYL\r
# 1  2022-01-28  SLCYL\r
# ...

# %%
headers = ['id_barang', 'nama_barang', 'jumlah_barang', 'unit', 'isi_unit', 'total_barang', 'harga_satuan (IDR)', 'harga (IDR)', 'id_customer', 'id_cabang', 'cabang_sales','nama_cabang', 'grup', 'date', 'lini']

df.columns = headers
df.head()
# Out:
#   id_barang                                nama_barang  jumlah_barang unit  \
# 0   BRG0005  KLORPROMAZINA TABLET SALUT SELAPUT 100 MG              1  DUS
# 1   BRG0010                                PARACETAMOL              4  DUS
# 2   BRG0005  KLORPROMAZINA TABLET SALUT SELAPUT 100 MG             12  DUS
# 3   BRG0010                                PARACETAMOL             15  DUS
# 4   BRG0005  KLORPROMAZINA TABLET SALUT SELAPUT 100 MG             18  DUS
#
#    isi_unit  total_barang  harga_satuan (IDR)  harga (IDR) id_customer  \
# 0        10            10                5648        56480   CUST55384
# 1         1             4                6940        27760   CUST55389
# 2        10           120                5648       677760   CUST55394
# 3         1            15                6940       104100   CUST55399
# 4        10           180                5648      1016640   CUST55404
#
#   id_cabang cabang_sales       nama_cabang      grup        date     lini
# ...

# %% [markdown]
# # Dataset Describe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_barang      59 non-null     object
#  1   nama_barang    59 non-null     object
#  2   jumlah_barang  59 non-null     int64
#  3   unit           59 non-null     object
#  4   isi_unit       59 non-null     int64
#  5   total_barang   59 non-null     int64
#  6   harga_satuan   59 non-null     int64
#  7   harga          59 non-null     int64
#  8   id_customer    59 non-null     object
#  9   id_cabang      59 non-null     object
#  10  cabang_sales   59 non-null     object
#  11  nama_cabang    59 non-null     object
#  12  grup           59 non-null     object
#  13  date           59 non-null     object
#  14  lini           59 non-null     object
# dtypes: int64(5), object(10)
# memory usage: 7.0+ KB

# %% [markdown]
# column date must be datetime type

# %%
df.describe()
# Out:
#        jumlah_barang   isi_unit  total_barang  harga_satuan (IDR)  \
# count      59.000000  59.000000     59.000000           59.000000
# mean       28.169492   6.338983    156.305085         6173.559322
# std        30.459217   4.459048    218.992305          640.121117
# min         1.000000   1.000000      4.000000         5648.000000
# 25%         9.000000   1.000000     14.500000         5648.000000
# 50%        14.000000  10.000000     90.000000         5648.000000
# 75%        34.000000  10.000000    180.000000         6940.000000
# max       130.000000  10.000000   1000.000000         6940.000000
#
#         harga (IDR)
# count  5.900000e+01
# mean   9.008115e+05
# std    1.230335e+06
# min    2.776000e+04
# 25%    1.006300e+05
# 50%    5.413200e+05
# 75%    1.016640e+06
# max    5.648000e+06

# %% [markdown]
# looks like there are not Null values

# %% [markdown]
# # Change Column type

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

df.head()
# Out:
#   id_barang                                nama_barang  jumlah_barang unit  \
# 0   BRG0005  KLORPROMAZINA TABLET SALUT SELAPUT 100 MG              1  DUS
# 1   BRG0010                                PARACETAMOL              4  DUS
# 2   BRG0005  KLORPROMAZINA TABLET SALUT SELAPUT 100 MG             12  DUS
# 3   BRG0010                                PARACETAMOL             15  DUS
# 4   BRG0005  KLORPROMAZINA TABLET SALUT SELAPUT 100 MG             18  DUS
#
#    isi_unit  total_barang  harga_satuan (IDR)  harga (IDR) id_customer  \
# 0        10            10                5648        56480   CUST55384
# 1         1             4                6940        27760   CUST55389
# 2        10           120                5648       677760   CUST55394
# 3         1            15                6940       104100   CUST55399
# 4        10           180                5648      1016640   CUST55404
#
#   id_cabang cabang_sales       nama_cabang      grup       date     lini
# ...

# %% [markdown]
# # Check Missing and Duplicated Values

# %%
df.isnull().sum()
# Out:
# id_barang             0
# nama_barang           0
# jumlah_barang         0
# unit                  0
# isi_unit              0
# total_barang          0
# harga_satuan (IDR)    0
# harga (IDR)           0
# id_customer           0
# id_cabang             0
# cabang_sales          0
# nama_cabang           0
# grup                  0
# date                  0
# lini                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Save Dataset

# %%
df.to_csv("data_salicyl_cleaned.csv", index=False)
